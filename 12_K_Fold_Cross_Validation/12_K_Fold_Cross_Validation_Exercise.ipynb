# %% [markdown]
# # **KFold Cross Validation Exercise**

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

import pandas as pd

from sklearn.datasets import load_iris
iris = load_iris()

# %%
dir(iris)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
df['target'] = iris.target
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %% [markdown]
# ### Training the Models & Cross-Validation

# %%
X = df.drop(['target'], axis='columns')
y = df.target

# %%
from sklearn.model_selection import StratifiedKFold
folds = StratifiedKFold(n_splits=5)

# %%
from sklearn.model_selection import cross_val_score

# %%
cross_val_results_l = cross_val_score(LogisticRegression(), X, y, cv=folds)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
print("Cross Validation Results for Logistic Regression (Accuracy):")
for i, result in enumerate(cross_val_results_l):
  print(f"Fold {i+1}: {result * 100 :.2f}%")
print(f'Mean Accuracy: {cross_val_results_l.mean() * 100 :.2f}%')
# Out:
# Cross Validation Results for Logistic Regression (Accuracy):
# Fold 1: 96.67%
# Fold 2: 100.00%
# Fold 3: 93.33%
# Fold 4: 96.67%
# Fold 5: 100.00%
# Mean Accuracy: 97.33%

# %%
cross_val_results_svm = cross_val_score(SVC(C=5), X, y, cv=folds)

# %%
print("Cross Validation Results for Support Vector Machine (Accuracy):")
for i, result in enumerate(cross_val_results_svm):
  print(f"Fold {i+1}: {result * 100 :.2f}%")
print(f"Mean Accuracy: {cross_val_results_svm.mean() * 100 :.2f}%")
# Out:
# Cross Validation Results for Support Vector Machine (Accuracy):
# Fold 1: 96.67%
# Fold 2: 100.00%
# Fold 3: 100.00%
# Fold 4: 96.67%
# Fold 5: 100.00%
# Mean Accuracy: 98.67%

# %%
cross_val_results_rf = cross_val_score(RandomForestClassifier(n_estimators=40), X, y, cv=folds)

# %%
print("Cross Validation Results for Random Forest Classifier (Accuracy):")
for i, result in enumerate(cross_val_results_rf):
  print(f"Fold {i+1}: {result * 100 :.2f}%")
print(f"Mean Accuracy: {cross_val_results_rf.mean() * 100 :.2f}%")
# Out:
# Cross Validation Results for Random Forest Classifier (Accuracy):
# Fold 1: 96.67%
# Fold 2: 96.67%
# Fold 3: 93.33%
# Fold 4: 96.67%
# Fold 5: 100.00%
# Mean Accuracy: 96.67%
