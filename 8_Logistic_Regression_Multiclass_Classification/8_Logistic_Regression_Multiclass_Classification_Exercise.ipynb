# %% [markdown]
# # Logistic Regression (Multiclass Classification) Exercise

# %%
import matplotlib.pyplot as plt
from sklearn import datasets

# %% [markdown]
# **Loading the Iris Dataset (his loads the Iris dataset, which contains information about three types of flowers: Setosa - Versicolor - Virginica):**

# %%
iris = datasets.load_iris()

# %% [markdown]
# **Listing all attributes of iris, such as: [data → The actual feature values]. [target → The class labels (0, 1, 2).] [target_names → The names of the classes (Setosa, Versicolor, Virginica).] [feature_names → The names of the features]:**

# %%
dir(iris)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
iris.data[0]
# Out:
# array([5.1, 3.5, 1.4, 0.2])

# %%
iris.target_names[0]
# Out:
# np.str_('setosa')

# %%
iris.target[5]
# Out:
# np.int64(0)

# %%
iris.target[67]
# Out:
# np.int64(1)

# %%
iris.target[100]
# Out:
# np.int64(2)

# %% [markdown]
# **Defining Features (X) and Target Labels (y):**

# %%
X = iris.data
y = iris.target

# %% [markdown]
# **Splitting Data into Training and Test Sets:**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %% [markdown]
# **Training the Logistic Regression Model:**

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# **Making Predictions:**

# %%
model.predict([[10, 3, 1, 0.3]])
# Out:
# array([0])

# %% [markdown]
# **Evaluating Model Performance:**

# %%
model.score(X_test, y_test)
# Out:
# 0.9333333333333333

# %%
y_predicted = model.predict(X_test)

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_predicted)
cm
# Out:
# array([[15,  0,  0],
#        [ 0, 11,  2],
#        [ 0,  1, 16]])

# %% [markdown]
# **Visualizing the Confusion Matrix:**

# %%
import seaborn as sn
plt.figure(figsize=(10, 7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')
